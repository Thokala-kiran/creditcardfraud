# %% [markdown]
# # Credit card Fraud Detection
# ![](https://media.istockphoto.com/photos/stacked-credit-cards-picture-id1203763961?k=20&m=1203763961&s=612x612&w=0&h=mrFgkoWWVdp0mtt_vw6OTEZCSjw3bUYhuJt5QWVdkXo=)
#
# It is important that credit card companies are able to recognize fraudulent credit card transactions so that customers are not charged for items that they did not purchase.
#
# The dataset contains transactions made by credit cards in September 2013 by European cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.

# %% [markdown]
# **Intaslling the required libraries**

# %%
# !pip install numpy pandas matlplotlib seaborn  --upgrade --quiet
# Out:
# ERROR: Could not find a version that satisfies the requirement matlplotlib (from versions: none)
# ERROR: No matching distribution found for matlplotlib

# %%
# !pip install opendatasets scikit-learn lightgbm graphviz xgboost --upgrade --quiet

# %%
import os
import opendatasets as od
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
od.download("https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud")
# Out:
# Skipping, found downloaded files in "./creditcardfraud" (use force=True to force download)

# %%
os.listdir("creditcardfraud")
# Out:
# ['creditcard.csv']

# %% [markdown]
# **Converting the csv file into the data frame**

# %%
credit_df=pd.read_csv('./creditcardfraud/creditcard.csv')

# %%
credit_df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# No nulls in the datssets

# %%
credit_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
credit_df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# frauds in the datasets are `492`

# %%
credit_df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V20       V21  \
# ...

# %% [markdown]
# Dropping unwanted columns

# %%
credit_df=credit_df.drop(['Time','Amount'],axis=1)

# %%
credit_df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Class'],
#       dtype='object')

# %%
#ranging the values between 0 and 1 
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler().fit(inputs)
scaler.transform(inputs)
# Out:
# array([[0.93519234, 0.76649042, 0.8813649 , ..., 0.39455679, 0.41897614,
#         0.31269663],
#        [0.97854195, 0.77006665, 0.84029849, ..., 0.44601297, 0.41634514,
#         0.31342266],
#        [0.93521702, 0.75311767, 0.86814082, ..., 0.40272718, 0.41548927,
#         0.31191132],
#        ...,
#        [0.99090481, 0.76407969, 0.781102  , ..., 0.41117652, 0.41659318,
#         0.31258486],
#        [0.954209  , 0.77285574, 0.84958713, ..., 0.51474558, 0.41851953,
#         0.31524516],
#        [0.94923176, 0.7652564 , 0.84960146, ..., 0.29178597, 0.41646637,
#         0.31340084]])

# %%
import numpy as np
fraud=len(credit_df[credit_df.Class==1])
#dividing the fraud and normal indices
fraud_indices=np.array(credit_df[credit_df.Class==1].index)
normal_indices=np.array(credit_df[credit_df.Class==0].index)

# %%
#we now randomly get the normal indices values equal to the fraud indices
random_normal_indices=np.random.choice(normal_indices,fraud,replace=False)
#we now joint the fraud and random normal indices
real_data=np.concatenate([fraud_indices,random_normal_indices])

# %%
#combine the indices with the dataset
real_data=credit_df.iloc[real_data,:]
#divide the input and target columns
input_cols=real_data.iloc[:,real_data.columns!='Class']
targets=real_data.iloc[:,real_data.columns=='Class'];

# %%
input_cols
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 541    -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 623    -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4920   -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6108   -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 6329    1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
# ...          ...       ...       ...       ...       ...       ...       ...
# 51433  -4.376483 -3.704106  1.187411  0.203134  3.596434 -0.610099 -2.194108
# 64084  -1.272412  0.495955  1.893023 -0.000451 -0.228222  1.847335 -0.572307
# 11618  -0.852067 -0.106879  2.131735 -1.282653 -0.154801 -0.957260 -0.104426
# 145348  1.977068  0.246335 -1.591469  1.399868  0.524733 -1.106619  0.775826
# 259159  1.948889 -0.005007 -1.695613  0.476276  0.044539 -1.268789  0.142616
#
# ...

# %%
#splitting the data into the train and test sets
from sklearn.model_selection import train_test_split

# %%
train_inputs,test_inputs,train_targets,test_targets=train_test_split(input_cols,targets,test_size=0.2,random_state=4)

# %% [markdown]
# creating the model with help of MLPclassfier

# %%
from sklearn.neural_network import MLPClassifier
mplc=MLPClassifier(hidden_layer_sizes=200,max_iter=10000).fit(train_inputs,train_targets)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
testpreds=mplc.predict(test_inputs)

# %%
from sklearn.metrics import recall_score
recall=recall_score(testpreds,test_targets)
recall
# Out:
# 0.956989247311828

# %% [markdown]
# model is created with the accuracy of `96%`
